# %%
import kagglehub
import numpy as np
import pandas as pd
import keras
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from keras.layers import Input, Dense, Dropout, LSTM, GRU, SimpleRNN
from keras.models import Sequential

# Download latest version
path = kagglehub.dataset_download("fedesoriano/electric-power-consumption")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/aqr/.cache/kagglehub/datasets/fedesoriano/electric-power-consumption/versions/1

# %%
_df = pd.read_csv(path + "/powerconsumption.csv")
_df.head()
# Out:
#         Datetime  Temperature  ...  PowerConsumption_Zone2  PowerConsumption_Zone3
# 0  1/1/2017 0:00        6.559  ...             16128.87538             20240.96386
# 1  1/1/2017 0:10        6.414  ...             19375.07599             20131.08434
# 2  1/1/2017 0:20        6.313  ...             19006.68693             19668.43373
# 3  1/1/2017 0:30        6.121  ...             18361.09422             18899.27711
# 4  1/1/2017 0:40        5.921  ...             17872.34043             18442.40964
#
# [5 rows x 9 columns]

# %% [markdown]
# ## Understand Data Quality & Structure

# %%
_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52416 entries, 0 to 52415
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Datetime                52416 non-null  object
#  1   Temperature             52416 non-null  float64
#  2   Humidity                52416 non-null  float64
#  3   WindSpeed               52416 non-null  float64
#  4   GeneralDiffuseFlows     52416 non-null  float64
#  5   DiffuseFlows            52416 non-null  float64
#  6   PowerConsumption_Zone1  52416 non-null  float64
#  7   PowerConsumption_Zone2  52416 non-null  float64
#  8   PowerConsumption_Zone3  52416 non-null  float64
# dtypes: float64(8), object(1)
# memory usage: 3.6+ MB

# %%
_df.describe()
# Out:
#         Temperature  ...  PowerConsumption_Zone3
# count  52416.000000  ...            52416.000000
# mean      18.810024  ...            17835.406218
# std        5.815476  ...             6622.165099
# min        3.247000  ...             5935.174070
# 25%       14.410000  ...            13129.326630
# 50%       18.780000  ...            16415.117470
# 75%       22.890000  ...            21624.100420
# max       40.010000  ...            47598.326360
#
# [8 rows x 8 columns]

# %% [markdown]
# we will work with zone one

# %% [markdown]
# ### Computing Power Consumption Columns

# %%
_df["PowerConsumptionAvg"] = (
    _df["PowerConsumption_Zone1"]
    + _df["PowerConsumption_Zone2"]
    + _df["PowerConsumption_Zone3"]
) / 3
ec_df = _df.drop(
    ["PowerConsumption_Zone1", "PowerConsumption_Zone2", "PowerConsumption_Zone3"],
    axis=1,
)
ec_df.head(10)
# Out:
#         Datetime  Temperature  ...  DiffuseFlows  PowerConsumptionAvg
# 0  1/1/2017 0:00        6.559  ...         0.119         23475.178480
# 1  1/1/2017 0:10        6.414  ...         0.085         23106.947957
# 2  1/1/2017 0:20        6.313  ...         0.100         22601.073977
# 3  1/1/2017 0:30        6.121  ...         0.096         21829.744030
# 4  1/1/2017 0:40        5.921  ...         0.085         21216.815423
# 5  1/1/2017 0:50        5.853  ...         0.108         20723.781327
# 6  1/1/2017 1:00        5.641  ...         0.096         20312.453550
# 7  1/1/2017 1:10        5.496  ...         0.093         19855.583747
# 8  1/1/2017 1:20        5.678  ...         0.141         19343.539770
# 9  1/1/2017 1:30        5.491  ...         0.111         19004.306757
#
# [10 rows x 7 columns]

# %% [markdown]
# ### Sort with Datetime

# %%
ec_df["Datetime"] = pd.to_datetime(ec_df["Datetime"])
print(ec_df["Datetime"].notna().count())
ec_df.sort_values("Datetime", inplace=True, ascending=True)
print(ec_df.head(10))
# Out:
# 52416
#              Datetime  Temperature  ...  DiffuseFlows  PowerConsumptionAvg
# 0 2017-01-01 00:00:00        6.559  ...         0.119         23475.178480
# 1 2017-01-01 00:10:00        6.414  ...         0.085         23106.947957
# 2 2017-01-01 00:20:00        6.313  ...         0.100         22601.073977
# 3 2017-01-01 00:30:00        6.121  ...         0.096         21829.744030
# 4 2017-01-01 00:40:00        5.921  ...         0.085         21216.815423
# 5 2017-01-01 00:50:00        5.853  ...         0.108         20723.781327
# 6 2017-01-01 01:00:00        5.641  ...         0.096         20312.453550
# 7 2017-01-01 01:10:00        5.496  ...         0.093         19855.583747
# 8 2017-01-01 01:20:00        5.678  ...         0.141         19343.539770
# 9 2017-01-01 01:30:00        5.491  ...         0.111         19004.306757
#
# [10 rows x 7 columns]

# %% [markdown]
# ### Remove Datetime Column

# %%
ecdf_timeindex = ec_df.drop("Datetime", axis=1)
ecdf_timeindex.corr()
# Out:
#                      Temperature  Humidity  ...  DiffuseFlows  PowerConsumptionAvg
# Temperature             1.000000 -0.460243  ...      0.196522             0.488238
# Humidity               -0.460243  1.000000  ...     -0.256886            -0.299059
# WindSpeed               0.477109 -0.135853  ...     -0.000972             0.221706
# GeneralDiffuseFlows     0.460294 -0.468138  ...      0.564718             0.150368
# DiffuseFlows            0.196522 -0.256886  ...      1.000000             0.032068
# PowerConsumptionAvg     0.488238 -0.299059  ...      0.032068             1.000000
#
# [6 rows x 6 columns]

# %% [markdown]
# ## Preprocessing Steps

# %%
x = ecdf_timeindex.drop("PowerConsumptionAvg", axis=1).values
y = ecdf_timeindex["PowerConsumptionAvg"].values
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.15, random_state=42)
print(f"Train set shape: {xtrain.shape}")
print(f"Test set shape: {xtest.shape}")
# Out:
# Train set shape: (44553, 5)
# Test set shape: (7863, 5)

# %% [markdown]
# ### Scaling

# %%
# رعایت اصل عدم تداخل داده تست و یادگیری و استانداردسازی
scaler = StandardScaler().fit(xtrain)
xtrain_scaled = scaler.transform(xtrain)
xtest_scaled = scaler.transform(xtest)

xtrain_scaled = xtrain_scaled.astype(np.float32)
xtest_scaled = xtest_scaled.astype(np.float32)

print(xtest_scaled[:5])
# Out:
# [[ 0.67960966 -2.4792528  -0.797708    1.6307168   4.750212  ]
#  [-0.49832723 -0.8882141  -0.797708   -0.6213205  -0.44979367]
#  [-0.6429861  -0.7085703  -0.8015402   0.80411136 -0.2780338 ]
#  [-1.1010727   0.26176372 -0.7994112  -0.6932869  -0.6044098 ]
#  [-0.72909266  0.7961879  -0.799837   -0.693453   -0.60395867]]

# %% [markdown]
# ### TargetScaling

# %%
target_scaler = MinMaxScaler(feature_range=(0, 10)).fit(ytrain.reshape(-1, 1))
ytrain_scaled = target_scaler.transform(ytrain.reshape(-1, 1))
ytest_scaled = target_scaler.transform(ytest.reshape(-1, 1))

# %% [markdown]
# # Training With DeepModel

# %%
from keras.activations import relu, leaky_relu, elu, gelu, selu, tanh
import random, string


class DeepModel:
    def __init__(
        self,
        input_shape,
        hidden_layer_count=4,
        units_per_layer=[128, 128, 64, 32],
        activation_per_layer=(leaky_relu, leaky_relu, leaky_relu, relu),
        optimizer="adam",
        save_model=False
    ):
        if len(units_per_layer) != hidden_layer_count:
            raise ValueError("Length of units_per_layer must match hidden_layer_count")
        if len(activation_per_layer) != hidden_layer_count:
            raise ValueError(
                "Length of activation_per_layer must match hidden_layer_count"
            )

        self.model = Sequential()
        self.model.add(Input(shape=input_shape))
        for i in range(hidden_layer_count):
            self.model.add(
                Dense(units=units_per_layer[i], activation=activation_per_layer[i])
            )
        self.model.add(Dense(1))
        self.model.compile(optimizer=optimizer, loss="mse")
        self.callbacks = [
            keras.callbacks.EarlyStopping(monitor="val_loss", patience=10, verbose=1),
            keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.2, patience=5, verbose=1),
        ]
        self.modelname = ''.join(random.choices(string.ascii_letters + string.digits, k=6))
        self.save_model = save_model

    def learn(self, x_train, y_train):
        modelhistory = self.model.fit(x_train, y_train, validation_split=0.2, epochs=100, batch_size=128, callbacks=self.callbacks)
        if self.save_model:
            self.model.save(f"deep_model_{self.modelname}.keras")
        return modelhistory

    # x should already be scaled
    def predict(self, x):
        return self.model.predict(x)
    # x,y most be scaled
    def evaluate(self, x_test, y_test):
        return self.model.evaluate(x_test, y_test)

# %%
deep_one = DeepModel(input_shape=(xtrain_scaled.shape[1],), optimizer=keras.optimizers.RMSprop())
deep_one_history = deep_one.learn(xtrain_scaled, ytrain_scaled)
# Out:
# Epoch 1/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2917 - val_loss: 2.1547 - learning_rate: 0.0010
# Epoch 2/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.0355 - val_loss: 1.9694 - learning_rate: 0.0010
# Epoch 3/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.9973 - val_loss: 2.0693 - learning_rate: 0.0010
# Epoch 4/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.9778 - val_loss: 2.0454 - learning_rate: 0.0010
# Epoch 5/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.9591 - val_loss: 1.9448 - learning_rate: 0.0010
# Epoch 6/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.9451 - val_loss: 1.9056 - learning_rate: 0.0010
# Epoch 7/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.9381 - val_loss: 1.9338 - learning_rate: 0.0010
# Epoch 8/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.9284 - val_loss: 1.9319 - learning_rate: 0.0010
# Epoch 9/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.9202 - val_loss: 1.8957 - learning_rate: 0.0010
# Epoch 10/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.9061 - val_loss: 1.8540 - learning_rate: 0.0010
# Epoch 11/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.9066 - val_loss: 1.8791 - learning_rate: 0.0010
# Epoch 12/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8952 - val_loss: 1.8545 - learning_rate: 0.0010
# Epoch 13/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8912 - val_loss: 1.8690 - learning_rate: 0.0010
# Epoch 14/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8884 - val_loss: 1.9288 - learning_rate: 0.0010
# Epoch 15/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8827 - val_loss: 1.8445 - learning_rate: 0.0010
# Epoch 16/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8762 - val_loss: 1.8561 - learning_rate: 0.0010
# Epoch 17/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8722 - val_loss: 1.8440 - learning_rate: 0.0010
# Epoch 18/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8653 - val_loss: 1.8406 - learning_rate: 0.0010
# Epoch 19/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8632 - val_loss: 1.8680 - learning_rate: 0.0010
# Epoch 20/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8524 - val_loss: 1.8559 - learning_rate: 0.0010
# Epoch 21/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8550 - val_loss: 1.8445 - learning_rate: 0.0010
# Epoch 22/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8424 - val_loss: 1.8396 - learning_rate: 0.0010
# Epoch 23/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8433 - val_loss: 1.8363 - learning_rate: 0.0010
# Epoch 24/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8392 - val_loss: 1.8148 - learning_rate: 0.0010
# Epoch 25/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8357 - val_loss: 1.8399 - learning_rate: 0.0010
# Epoch 26/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8304 - val_loss: 1.8084 - learning_rate: 0.0010
# Epoch 27/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8297 - val_loss: 1.8346 - learning_rate: 0.0010
# Epoch 28/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8276 - val_loss: 1.8430 - learning_rate: 0.0010
# Epoch 29/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8183 - val_loss: 1.7944 - learning_rate: 0.0010
# Epoch 30/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8136 - val_loss: 1.8819 - learning_rate: 0.0010
# Epoch 31/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8063 - val_loss: 1.7930 - learning_rate: 0.0010
# Epoch 32/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8080 - val_loss: 1.8101 - learning_rate: 0.0010
# Epoch 33/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8052 - val_loss: 1.7824 - learning_rate: 0.0010
# Epoch 34/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8016 - val_loss: 1.8415 - learning_rate: 0.0010
# Epoch 35/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7955 - val_loss: 1.7827 - learning_rate: 0.0010
# Epoch 36/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7886 - val_loss: 1.7704 - learning_rate: 0.0010
# Epoch 37/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7853 - val_loss: 1.7683 - learning_rate: 0.0010
# Epoch 38/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7844 - val_loss: 1.7703 - learning_rate: 0.0010
# Epoch 39/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7804 - val_loss: 1.7644 - learning_rate: 0.0010
# Epoch 40/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7808 - val_loss: 1.8308 - learning_rate: 0.0010
# Epoch 41/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.7762 - val_loss: 1.7605 - learning_rate: 0.0010
# Epoch 42/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7729 - val_loss: 1.7539 - learning_rate: 0.0010
# Epoch 43/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7681 - val_loss: 1.7580 - learning_rate: 0.0010
# Epoch 44/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7668 - val_loss: 1.7814 - learning_rate: 0.0010
# Epoch 45/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7636 - val_loss: 1.7573 - learning_rate: 0.0010
# Epoch 46/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7581 - val_loss: 1.7834 - learning_rate: 0.0010
# Epoch 47/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7553 - val_loss: 1.7518 - learning_rate: 0.0010
# Epoch 48/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7489 - val_loss: 1.8352 - learning_rate: 0.0010
# Epoch 49/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7544 - val_loss: 1.7452 - learning_rate: 0.0010
# Epoch 50/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7455 - val_loss: 1.7291 - learning_rate: 0.0010
# Epoch 51/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7443 - val_loss: 1.7881 - learning_rate: 0.0010
# Epoch 52/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7392 - val_loss: 1.7471 - learning_rate: 0.0010
# Epoch 53/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7351 - val_loss: 1.8075 - learning_rate: 0.0010
# Epoch 54/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7380 - val_loss: 1.7337 - learning_rate: 0.0010
# Epoch 55/100
# 510/557 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7466
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7365 - val_loss: 1.7522 - learning_rate: 0.0010
# Epoch 56/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6585 - val_loss: 1.6737 - learning_rate: 2.0000e-04
# Epoch 57/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6478 - val_loss: 1.6626 - learning_rate: 2.0000e-04
# Epoch 58/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6440 - val_loss: 1.6611 - learning_rate: 2.0000e-04
# Epoch 59/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6401 - val_loss: 1.6726 - learning_rate: 2.0000e-04
# Epoch 60/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6370 - val_loss: 1.6597 - learning_rate: 2.0000e-04
# Epoch 61/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6346 - val_loss: 1.6477 - learning_rate: 2.0000e-04
# Epoch 62/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6317 - val_loss: 1.6621 - learning_rate: 2.0000e-04
# Epoch 63/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6308 - val_loss: 1.6656 - learning_rate: 2.0000e-04
# Epoch 64/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6280 - val_loss: 1.6495 - learning_rate: 2.0000e-04
# Epoch 65/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6257 - val_loss: 1.6514 - learning_rate: 2.0000e-04
# Epoch 66/100
# 538/557 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6048
# Epoch 66: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6259 - val_loss: 1.6534 - learning_rate: 2.0000e-04
# Epoch 67/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.6079 - val_loss: 1.6382 - learning_rate: 4.0000e-05
# Epoch 68/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6054 - val_loss: 1.6367 - learning_rate: 4.0000e-05
# Epoch 69/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6049 - val_loss: 1.6418 - learning_rate: 4.0000e-05
# Epoch 70/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6044 - val_loss: 1.6348 - learning_rate: 4.0000e-05
# Epoch 71/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6034 - val_loss: 1.6343 - learning_rate: 4.0000e-05
# Epoch 72/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6033 - val_loss: 1.6403 - learning_rate: 4.0000e-05
# Epoch 73/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6032 - val_loss: 1.6370 - learning_rate: 4.0000e-05
# Epoch 74/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6020 - val_loss: 1.6418 - learning_rate: 4.0000e-05
# Epoch 75/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6013 - val_loss: 1.6347 - learning_rate: 4.0000e-05
# Epoch 76/100
# 535/557 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5857
# Epoch 76: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.6014 - val_loss: 1.6357 - learning_rate: 4.0000e-05
# Epoch 77/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.5968 - val_loss: 1.6349 - learning_rate: 8.0000e-06
# Epoch 78/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.5967 - val_loss: 1.6358 - learning_rate: 8.0000e-06
# Epoch 79/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.5966 - val_loss: 1.6341 - learning_rate: 8.0000e-06
# Epoch 80/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.5965 - val_loss: 1.6354 - learning_rate: 8.0000e-06
# Epoch 81/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.5963 - val_loss: 1.6358 - learning_rate: 8.0000e-06
# Epoch 82/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.5963 - val_loss: 1.6348 - learning_rate: 8.0000e-06
# Epoch 83/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.5961 - val_loss: 1.6359 - learning_rate: 8.0000e-06
# Epoch 84/100
# 524/557 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6037
# Epoch 84: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.5958 - val_loss: 1.6375 - learning_rate: 8.0000e-06
# Epoch 85/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.5951 - val_loss: 1.6359 - learning_rate: 1.6000e-06
# Epoch 86/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.5949 - val_loss: 1.6352 - learning_rate: 1.6000e-06
# Epoch 87/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.5949 - val_loss: 1.6351 - learning_rate: 1.6000e-06
# Epoch 88/100
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.5948 - val_loss: 1.6350 - learning_rate: 1.6000e-06
# Epoch 89/100
# 516/557 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 1.6000
# Epoch 89: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 557/557 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.5948 - val_loss: 1.6346 - learning_rate: 1.6000e-06
# Epoch 89: early stopping

# %% [markdown]
# # Training With Recurrent Neural Networks

# %%
# rnn_mode = {'lstm':0, 'gru':1, 'simple_rnn':2}

# rnn_model = seq
